# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("practice-data.csv")
df.head()
# Out:
#    Unnamed: 0        x1        x2        x3        x4        x5  target
# 0           0 -2.185932 -0.451297 -1.203906  0.459129  0.521016       0
# 1           1 -2.195587  0.373123 -0.099474 -0.285703 -0.991147       0
# 2           2 -0.156196  1.541114  0.189818 -0.698405  2.103603       1
# 3           3  1.248188 -1.263570  1.134588 -0.710887  0.642475       1
# 4           4 -0.069608 -0.895679  0.059133 -0.929168  2.985811       1

# %%
df.drop("Unnamed: 0", axis=1, inplace=True)

# %%
df
# Out:
#           x1        x2        x3        x4        x5  target
# 0  -2.185932 -0.451297 -1.203906  0.459129  0.521016       0
# 1  -2.195587  0.373123 -0.099474 -0.285703 -0.991147       0
# 2  -0.156196  1.541114  0.189818 -0.698405  2.103603       1
# 3   1.248188 -1.263570  1.134588 -0.710887  0.642475       1
# 4  -0.069608 -0.895679  0.059133 -0.929168  2.985811       1
# ..       ...       ...       ...       ...       ...     ...
# 95  1.685168 -0.333731  2.289103  1.190477 -0.051928       1
# 96  0.173197 -0.151863  0.072567  0.455605  0.795792       1
# 97 -0.060021  1.178236  0.390696 -0.238761  1.050029       1
# 98  1.419681  2.571910  0.441864  0.067418 -0.213845       1
# 99  1.092127 -0.562441  0.661916 -1.470989  1.137641       1
#
# [100 rows x 6 columns]

# %%
sns.pairplot(df, hue="target")

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.drop("target", axis=1)
y = df["target"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=.7)

# %%
from sklearn.feature_selection import f_classif

# %%
f_classif(X_train, y_train)
# Out:
# (array([1.68582053e+02, 1.51085974e-01, 3.54921308e-01, 2.79787594e+00,
#         1.47272117e+00]),
#  array([4.41700198e-20, 6.98714129e-01, 5.53318240e-01, 9.89844869e-02,
#         2.29115258e-01]))

# %%
f_classif(X_test, y_test)
# Out:
# (array([9.04755070e+01, 1.51780805e-01, 5.30555447e-03, 3.08061441e-02,
#         6.36209621e-01]),
#  array([2.87122798e-10, 6.99786918e-01, 9.42451890e-01, 8.61936738e-01,
#         4.31799407e-01]))

# %%
from sklearn.feature_selection import mutual_info_classif

# %%
mutual_info_classif(X_train, y_train)
# Out:
# array([0.60185466, 0.        , 0.05745097, 0.08457559, 0.06933311])

# %%
mutual_info_classif(X_test, y_test)
# Out:
# array([0.6534248 , 0.        , 0.00170523, 0.03678459, 0.02091158])
