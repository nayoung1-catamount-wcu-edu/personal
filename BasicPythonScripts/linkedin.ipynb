# %%
import pandas as pd
import matplotlib as plt

# %%
file = "D:/LinkedIn/Archive/Connections.csv"

df = pd.read_csv(file)

df.columns
# Out:
# Index(['First Name', 'Last Name', 'Email Address', 'Company', 'Position',
#        'Connected On'],
#       dtype='object')
