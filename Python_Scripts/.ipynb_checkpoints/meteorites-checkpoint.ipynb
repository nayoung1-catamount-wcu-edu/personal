# %%
import pandas as pd
import geopandas as gps

# %%
data = pd.read_csv("https://data.nasa.gov/api/views/gh4g-9sfh/rows.csv?accessType=DOWNLOAD")
data
# Out:
#              name     id nametype              recclass  mass (g)   fall  \
# 0          Aachen      1    Valid                    L5      21.0   Fell
# 1          Aarhus      2    Valid                    H6     720.0   Fell
# 2            Abee      6    Valid                   EH4  107000.0   Fell
# 3        Acapulco     10    Valid           Acapulcoite    1914.0   Fell
# 4         Achiras    370    Valid                    L6     780.0   Fell
# ...           ...    ...      ...                   ...       ...    ...
# 45711  Zillah 002  31356    Valid               Eucrite     172.0  Found
# 45712      Zinder  30409    Valid  Pallasite, ungrouped      46.0  Found
# 45713        Zlin  30410    Valid                    H4       3.3  Found
# 45714   Zubkovsky  31357    Valid                    L6    2167.0  Found
# 45715  Zulu Queen  30414    Valid                  L3.7     200.0  Found
#
#                          year    reclat    reclong             GeoLocation
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45716 entries, 0 to 45715
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         45716 non-null  object
#  1   id           45716 non-null  int64
#  2   nametype     45716 non-null  object
#  3   recclass     45716 non-null  object
#  4   mass (g)     45585 non-null  float64
#  5   fall         45716 non-null  object
#  6   year         45425 non-null  object
#  7   reclat       38401 non-null  float64
#  8   reclong      38401 non-null  float64
#  9   GeoLocation  38401 non-null  object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 3.5+ MB

# %%
from sklearn.model_selection import train_test_split

# %%
dummies = pd.get_dummies(data['fall'])
dummies
# Out:
#        Fell  Found
# 0         1      0
# 1         1      0
# 2         1      0
# 3         1      0
# 4         1      0
# ...     ...    ...
# 45711     0      1
# 45712     0      1
# 45713     0      1
# 45714     0      1
# 45715     0      1
#
# [45716 rows x 2 columns]

# %%
#data_clean = data.drop("fall", axis =1)
data_dum = data.join(dummies).drop("fall", axis =1)

# %%
data_dum = data_dum.select_dtypes(exclude = "object")
data_dum = data_dum.drop("id", axis = 1)

# %%
data_dum = data_dum.dropna()

# %%
X = data_dum.drop("Fell", axis =1)
y = data_dum["Fell"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .3)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
lr.score(X_train, y_train)
# Out:
# 1.0

# %%
lr.score(X_test, y_test)
# Out:
# 1.0

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rfc = RandomForestRegressor().fit(X_train, y_train)

# %%
rfc.score(X_train, y_train)
# Out:
# 1.0

# %%
lr_pred = lr.predict(X)

# %%
import seaborn as sns

# %%
rfc.score(X_test, y_test)
# Out:
# 1.0

# %%
rfc_pred = rfc.predict(X)

# %%
import seaborn as sns

# %%
sns.scatterplot(y, rfc_pred, hue = data["fall"]);
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-2e66920f4b3e> in <module>
# ----> 1 sns.scatterplot(y, rfc_pred, hue = data["fall"]);
#
# c:\users\natha\appdata\local\programs\python\python37\lib\site-packages\seaborn\relational.py in scatterplot(x, y, hue, style, size, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, x_bins, y_bins, units, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend, ax, **kwargs)
#    1395         x_bins=x_bins, y_bins=y_bins,
#    1396         estimator=estimator, ci=ci, n_boot=n_boot,
# -> 1397         alpha=alpha, x_jitter=x_jitter, y_jitter=y_jitter, legend=legend,
#    1398     )
#    1399
#
# ...

# %%
sns.pairplot(data, hue = "fall");
