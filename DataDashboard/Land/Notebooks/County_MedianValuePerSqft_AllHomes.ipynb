# %%
#Imports
import pandas as pd
import pyodbc

# %%
# Watermark
print('Nathan Young\nJunior Data Analyst\nCenter for the Study of Free Enterprise')
# %load_ext watermark
# %watermark -a "Western Carolina University" -u -d -p pandas
# Out:
# Nathan Young
# Junior Data Analyst
# Center for the Study of Free Enterprise
# Western Carolina University
# last updated: 2020-01-28
#
# pandas 0.25.3

# %%
# Create backups
#df_backup = pd.read_csv('./Updates/STG_ZLLW_County_MedianValuePerSqft_AllHomes.txt')
#df_backup.to_csv('./Backups/STG_ZLLW_County_MedianValuePerSqft_AllHomes_BACKUP.txt')

# %%
#Load Land data
df_mvsf = pd.read_csv('http://files.zillowstatic.com/research/public/County/County_MedianValuePerSqft_AllHomes.csv', 
                      encoding='ISO-8859-1')

#Display table to ensure data loaded correctly
df_mvsf.head()
# Out:
#    RegionID          RegionName State                             Metro  \
# 0      3101  Los Angeles County    CA    Los Angeles-Long Beach-Anaheim
# 1       139         Cook County    IL          Chicago-Naperville-Elgin
# 2      1090       Harris County    TX  Houston-The Woodlands-Sugar Land
# 3      2402     Maricopa County    AZ           Phoenix-Mesa-Scottsdale
# 4      2841    San Diego County    CA                San Diego-Carlsbad
#
#    StateCodeFIPS  MunicipalCodeFIPS  SizeRank  1996-04  1996-05  1996-06  ...  \
# 0              6                 37         1   1019.0   1019.0   1019.0  ...
# 1             17                 31         2    463.0    463.0    463.0  ...
# 2             48                201         3    166.0    166.0    166.0  ...
# 3              4                 13         4    454.0    454.0    454.0  ...
# 4              6                 73         5    897.0    897.0    897.0  ...
#
#    2019-03  2019-04  2019-05  2019-06  2019-07  2019-08  2019-09  2019-10  \
# 0     1020     1020     1020     1020     1020     1020     1020     1020
# 1      464      464      464      464      464      464      464      464
# 2      166      166      166      166      166      166      166      166
# 3      454      454      454      454      454      454      454      454
# 4      898      898      898      898      898      898      898      898
#
#    2019-11  2019-12
# 0     1020     1020
# 1      464      464
# 2      166      166
# 3      454      454
# 4      898      898
#
# [5 rows x 292 columns]

# %%
#Filter data to NC
filter1 = df_mvsf['State'] == "NC"
df_mvsf_nc = df_mvsf[filter1]

#Check to ensure filter worked
df_mvsf_nc.head(5)
# Out:
#      RegionID          RegionName State                       Metro  \
# 48       3102  Mecklenburg County    NC  Charlotte-Concord-Gastonia
# 55        324         Wake County    NC                     Raleigh
# 134      2312     Guilford County    NC       Greensboro-High Point
# 183      1712      Forsyth County    NC               Winston-Salem
# 198      2912   Cumberland County    NC                Fayetteville
#
#      StateCodeFIPS  MunicipalCodeFIPS  SizeRank  1996-04  1996-05  1996-06  \
# 48              37                119        49    191.0    191.0    191.0
# 55              37                183        56    221.0    221.0    221.0
# 134             37                 81       135    144.0    144.0    144.0
# 183             37                 67       184    190.0    190.0    190.0
# 198             37                 51       199    148.0    148.0    148.0
#
#      ...  2019-03  2019-04  2019-05  2019-06  2019-07  2019-08  2019-09  \
# 48   ...      191      191      191      191      191      191      191
# 55   ...      221      221      221      221      221      221      221
# 134  ...      144      144      144      144      144      144      144
# 183  ...      190      190      190      190      190      190      190
# 198  ...      148      148      148      148      148      148      148
#
#      2019-10  2019-11  2019-12
# 48       191      191      191
# 55       221      221      221
# 134      144      144      144
# 183      190      190      190
# 198      148      148      149
#
# [5 rows x 292 columns]

# %%
#View data types of dataframe
df_mvsf_nc.dtypes
# Out:
# RegionID          int64
# RegionName       object
# State            object
# Metro            object
# StateCodeFIPS     int64
#                   ...
# 2019-08           int64
# 2019-09           int64
# 2019-10           int64
# 2019-11           int64
# 2019-12           int64
# Length: 292, dtype: object

# %%
#Change MunicipalCodeFIPS dtype to add leading 0's
df_mvsf_nc.loc[ :, 'MunicipalCodeFIPS'] = df_mvsf_nc['MunicipalCodeFIPS'].astype(str)
df_mvsf_nc.dtypes
# Out:
# c:\users\natha\appdata\local\programs\python\python37\lib\site-packages\pandas\core\indexing.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# RegionID          int64
# RegionName       object
# State            object
# Metro            object
# StateCodeFIPS     int64
#                   ...
# 2019-08           int64
# 2019-09           int64
# 2019-10           int64
# 2019-11           int64
# 2019-12           int64
# Length: 292, dtype: object

# %%
#Add leading 0's and check to ensure they were added
df_mvsf_nc.loc[ :, 'MunicipalCodeFIPS'] = df_mvsf_nc['MunicipalCodeFIPS'].str.zfill(3)
df_mvsf_nc.head(5)
# Out:
#      RegionID          RegionName State                       Metro  \
# 48       3102  Mecklenburg County    NC  Charlotte-Concord-Gastonia
# 55        324         Wake County    NC                     Raleigh
# 134      2312     Guilford County    NC       Greensboro-High Point
# 183      1712      Forsyth County    NC               Winston-Salem
# 198      2912   Cumberland County    NC                Fayetteville
#
#      StateCodeFIPS MunicipalCodeFIPS  SizeRank  1996-04  1996-05  1996-06  \
# 48              37               119        49    191.0    191.0    191.0
# 55              37               183        56    221.0    221.0    221.0
# 134             37               081       135    144.0    144.0    144.0
# 183             37               067       184    190.0    190.0    190.0
# 198             37               051       199    148.0    148.0    148.0
#
#      ...  2019-03  2019-04  2019-05  2019-06  2019-07  2019-08  2019-09  \
# 48   ...      191      191      191      191      191      191      191
# 55   ...      221      221      221      221      221      221      221
# 134  ...      144      144      144      144      144      144      144
# 183  ...      190      190      190      190      190      190      190
# 198  ...      148      148      148      148      148      148      148
#
#      2019-10  2019-11  2019-12
# 48       191      191      191
# 55       221      221      221
# 134      144      144      144
# 183      190      190      190
# 198      148      148      149
#
# [5 rows x 292 columns]

# %%
# Set Index to Region Name
df_mvsf_nc.set_index(df_mvsf_nc['RegionName'], inplace = True)
df_mvsf_nc
# Out:
#                     RegionID          RegionName State  \
# RegionName
# Mecklenburg County      3102  Mecklenburg County    NC
# Wake County              324         Wake County    NC
# Guilford County         2312     Guilford County    NC
# Forsyth County          1712      Forsyth County    NC
# Cumberland County       2912   Cumberland County    NC
# ...                      ...                 ...   ...
# Jones County             575        Jones County    NC
# Camden County            910       Camden County    NC
# Graham County           1049       Graham County    NC
# Hyde County              186         Hyde County    NC
# Tyrrell County          2059      Tyrrell County    NC
#
#                                          Metro  StateCodeFIPS  \
# RegionName
# Mecklenburg County  Charlotte-Concord-Gastonia             37
# Wake County                            Raleigh             37
# Guilford County          Greensboro-High Point             37
# Forsyth County                   Winston-Salem             37
# Cumberland County                 Fayetteville             37
# ...                                        ...            ...
# Jones County                          New Bern             37
# Camden County                   Elizabeth City             37
# Graham County                              NaN             37
# Hyde County                                NaN             37
# Tyrrell County                Kill Devil Hills             37
#
#                    MunicipalCodeFIPS  SizeRank  1996-04  1996-05  1996-06  \
# RegionName
# Mecklenburg County               119        49    191.0    191.0    191.0
# Wake County                      183        56    221.0    221.0    221.0
# Guilford County                  081       135    144.0    144.0    144.0
# Forsyth County                   067       184    190.0    190.0    190.0
# Cumberland County                051       199    148.0    148.0    148.0
# ...                              ...       ...      ...      ...      ...
# Jones County                     103      2403      NaN      NaN      NaN
# Camden County                    029      2419      NaN      NaN      NaN
# Graham County                    075      2503      NaN      NaN      NaN
# Hyde County                      095      2719      NaN      NaN      NaN
# Tyrrell County                   177      2772      NaN      NaN      NaN
#
#                     ...  2019-03  2019-04  2019-05  2019-06  2019-07  2019-08  \
# RegionName          ...
# Mecklenburg County  ...      191      191      191      191      191      191
# Wake County         ...      221      221      221      221      221      221
# Guilford County     ...      144      144      144      144      144      144
# Forsyth County      ...      190      190      190      190      190      190
# Cumberland County   ...      148      148      148      148      148      148
# ...                 ...      ...      ...      ...      ...      ...      ...
# Jones County        ...       67       67       67       67       67       67
# Camden County       ...      554      554      554      554      554      554
# Graham County       ...       78       78       78       78       78       78
# Hyde County         ...       71       71       71       71       71       71
# Tyrrell County      ...       63       63       63       63       63       63
#
#                     2019-09  2019-10  2019-11  2019-12
# RegionName
# Mecklenburg County      191      191      191      191
# Wake County             221      221      221      221
# Guilford County         144      144      144      144
# Forsyth County          190      190      190      190
# Cumberland County       148      148      148      149
# ...                     ...      ...      ...      ...
# Jones County             67       67       67       67
# Camden County           554      554      554      554
# Graham County            78       78       78       78
# Hyde County              71       71       71       71
# Tyrrell County           63       63       63       63
#
# [100 rows x 292 columns]

# %%
# Drop Region Name column
df_mvsf_nc.drop('RegionName', axis = 1, inplace = True)
df_mvsf_nc
# Out:
# c:\users\natha\appdata\local\programs\python\python37\lib\site-packages\pandas\core\frame.py:4117: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#                     RegionID State                       Metro  StateCodeFIPS  \
# RegionName
# Mecklenburg County      3102    NC  Charlotte-Concord-Gastonia             37
# Wake County              324    NC                     Raleigh             37
# Guilford County         2312    NC       Greensboro-High Point             37
# Forsyth County          1712    NC               Winston-Salem             37
# Cumberland County       2912    NC                Fayetteville             37
# ...                      ...   ...                         ...            ...
# Jones County             575    NC                    New Bern             37
# Camden County            910    NC              Elizabeth City             37
# Graham County           1049    NC                         NaN             37
# Hyde County              186    NC                         NaN             37
# Tyrrell County          2059    NC            Kill Devil Hills             37
#
#                    MunicipalCodeFIPS  SizeRank  1996-04  1996-05  1996-06  \
# RegionName
# Mecklenburg County               119        49    191.0    191.0    191.0
# Wake County                      183        56    221.0    221.0    221.0
# Guilford County                  081       135    144.0    144.0    144.0
# Forsyth County                   067       184    190.0    190.0    190.0
# Cumberland County                051       199    148.0    148.0    148.0
# ...                              ...       ...      ...      ...      ...
# Jones County                     103      2403      NaN      NaN      NaN
# Camden County                    029      2419      NaN      NaN      NaN
# Graham County                    075      2503      NaN      NaN      NaN
# Hyde County                      095      2719      NaN      NaN      NaN
# Tyrrell County                   177      2772      NaN      NaN      NaN
#
#                     1996-07  ...  2019-03  2019-04  2019-05  2019-06  2019-07  \
# RegionName                   ...
# Mecklenburg County    191.0  ...      191      191      191      191      191
# Wake County           221.0  ...      221      221      221      221      221
# Guilford County       144.0  ...      144      144      144      144      144
# Forsyth County        190.0  ...      190      190      190      190      190
# Cumberland County     148.0  ...      148      148      148      148      148
# ...                     ...  ...      ...      ...      ...      ...      ...
# Jones County            NaN  ...       67       67       67       67       67
# Camden County           NaN  ...      554      554      554      554      554
# Graham County           NaN  ...       78       78       78       78       78
# Hyde County             NaN  ...       71       71       71       71       71
# Tyrrell County          NaN  ...       63       63       63       63       63
#
#                     2019-08  2019-09  2019-10  2019-11  2019-12
# RegionName
# Mecklenburg County      191      191      191      191      191
# Wake County             221      221      221      221      221
# Guilford County         144      144      144      144      144
# Forsyth County          190      190      190      190      190
# Cumberland County       148      148      148      148      149
# ...                     ...      ...      ...      ...      ...
# Jones County             67       67       67       67       67
# Camden County           554      554      554      554      554
# Graham County            78       78       78       78       78
# Hyde County              71       71       71       71       71
# Tyrrell County           63       63       63       63       63
#
# [100 rows x 291 columns]

# %%
#Save to csv file for export in Excel
#df_mvsf_nc.to_csv('./Updates/STG_ZLLW_County_MedianValuePerSqft_AllHomes.txt', sep = '\t')

# %%
#Connect to database and create cursor
conn = pyodbc.connect('Driver={SQL Server};'
                      'Server=TITANIUM-BOOK;'
                      'Database=DataDashboard;'
                      'Trusted_Connection=yes;')

c = conn.cursor()

# %%
#Verify data is in database
c.execute('select top(1) * from dbo.STG_ZLLW_County_MedianValuePerSqft_AllHomes')
for row in c:
    print(row)
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-13-b350f37e1ca0> in <module>
#       1 #Verify data is in database
# ----> 2 c.execute('select top(1) * from dbo.STG_ZLLW_County_MedianValuePerSqft_AllHomes')
#       3 for row in c:
#       4     print(row)
#
# ProgrammingError: ('42S02', "[42S02] [Microsoft][ODBC SQL Server Driver][SQL Server]Invalid object name 'dbo.STG_ZLLW_County_MedianValuePerSqft_AllHomes'. (208) (SQLExecDirectW)")

# %%
#Drop old backup table
#c.execute('drop table STG_ZLLW_County_MedianValuePerSqft_AllHomes_BACKUP')

# %%
#Create new backup
c.execute("sp_rename 'dbo.STG_ZLLW_County_MedianValuePerSqft_AllHomes','STG_ZLLW_County_MedianValuePerSqft_AllHomes_BACKUP';")
conn.commit()

# %%
#Verify backups are created
c.execute('select top(1) * from dbo.STG_ZLLW_County_MedianValuePerSqft_AllHomes_BACKUP')
for row in c:
    print(row)

# %%
conn.close()
