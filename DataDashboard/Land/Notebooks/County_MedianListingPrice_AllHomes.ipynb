# %%
#Imports
import pandas as pd
import watermark

# %%
# Watermark
print('Nathan Young\nCenter for the Study of Free Enterprise')
# %watermark -a "Western Carolina University" -u -d -p pandas
# Out:
# Nathan Young
# Center for Study of Free Enterprise
# Western Carolina University
# last updated: 2019-12-25
#
# pandas 0.25.3

# %%
# Create Backups
#df_backup = pd.read_csv('./Updates/STG_ZLLW_County_MedianListingPrice_AllHomes.txt')
#df_backup.to_csv('./Backups/STG_ZLLW_County_MedianListingPrice_AllHomes_BACKUP.txt')

# %%
#Load Land data
df_mlp = pd.read_csv('http://files.zillowstatic.com/research/public/County/County_MedianListingPrice_AllHomes.csv',
                     encoding='ISO-8859-1')

#Display table to ensure data loaded correctly
df_mlp.head()
# Out:
#            RegionName State                             Metro  StateCodeFIPS  \
# 0  Los Angeles County    CA    Los Angeles-Long Beach-Anaheim              6
# 1         Cook County    IL          Chicago-Naperville-Elgin             17
# 2       Harris County    TX  Houston-The Woodlands-Sugar Land             48
# 3     Maricopa County    AZ           Phoenix-Mesa-Scottsdale              4
# 4    San Diego County    CA                San Diego-Carlsbad              6
#
#    MunicipalCodeFIPS  SizeRank   2010-01   2010-02   2010-03   2010-04  ...  \
# 0                 37         1  399000.0  389000.0  399000.0  398894.0  ...
# 1                 31         2  244900.0  249000.0  249000.0  249000.0  ...
# 2                201         3  149900.0  152900.0  154788.5  154900.0  ...
# 3                 13         4  179900.0  176000.0  174900.0  169900.0  ...
# 4                 73         5  399000.0  399000.0  399500.0  399990.0  ...
#
#     2019-02   2019-03   2019-04   2019-05   2019-06   2019-07   2019-08  \
# 0  650000.0  665000.0  675000.0  679000.0  689000.0  695000.0  689000.0
# 1  289900.0  299000.0  300000.0  300000.0  299900.0  299000.0  292900.0
# 2  279900.0  280000.0  286000.0  284995.0  283997.5  279294.5  275000.0
# 3  310000.0  315000.0  318616.0  319000.0  319900.0  317000.0  315000.0
# 4  639000.0  643950.0  650000.0  659800.0  655995.0  649990.0  650000.0
#
#     2019-09   2019-10   2019-11
# 0  689000.0  690000.0  695000.0
# 1  289999.0  288000.0  284900.0
# 2  274999.0  271990.0  274000.0
# 3  319000.0  319900.0  320000.0
# 4  658000.0  649900.0  650000.0
#
# [5 rows x 125 columns]

# %%
#Filter data to NC
filter1 = df_mlp['State'] == "NC"
df_mlp_nc = df_mlp[filter1]

#Check to ensure filter worked
df_mlp_nc.head(5)
# Out:
#              RegionName State                       Metro  StateCodeFIPS  \
# 48   Mecklenburg County    NC  Charlotte-Concord-Gastonia             37
# 55          Wake County    NC                     Raleigh             37
# 134     Guilford County    NC       Greensboro-High Point             37
# 183      Forsyth County    NC               Winston-Salem             37
# 198   Cumberland County    NC                Fayetteville             37
#
#      MunicipalCodeFIPS  SizeRank   2010-01   2010-02   2010-03   2010-04  ...  \
# 48                 119        49  189900.0  194500.0  190000.0  194000.0  ...
# 55                 183        56  247945.0  245000.0  239900.0  239900.0  ...
# 134                 81       135  159900.0  159900.0  159900.0  159900.0  ...
# 183                 67       184  154900.0  156800.0  159900.0  159900.0  ...
# 198                 51       199       NaN       NaN       NaN       NaN  ...
#
#       2019-02   2019-03   2019-04   2019-05   2019-06   2019-07   2019-08  \
# 48   318990.0  318005.0  324999.0  321900.0  320000.0  318854.0  314999.0
# 55   357900.0  359000.0  364900.0  359900.0  359900.0  358490.0  357515.0
# 134  196900.0  208000.0  212945.0  214500.0  214379.0  214900.0  207900.0
# 183  200000.0  215000.0  224900.0  219900.0  225000.0  227400.0  220000.0
# 198  163000.0  165000.0  172000.0  169500.0  169000.0  168000.0  169000.0
#
#       2019-09   2019-10   2019-11
# 48   315000.0  315000.0  318999.0
# 55   359000.0  352990.0  350000.0
# 134  209700.0  214900.0  209900.0
# 183  216900.0  220000.0  225000.0
# 198  163000.0  161430.0  162900.0
#
# [5 rows x 125 columns]

# %%
#View data types of dataframe
df_mlp_nc.dtypes
# Out:
# RegionName            object
# State                 object
# Metro                 object
# StateCodeFIPS          int64
# MunicipalCodeFIPS      int64
#                       ...
# 2019-07              float64
# 2019-08              float64
# 2019-09              float64
# 2019-10              float64
# 2019-11              float64
# Length: 125, dtype: object

# %%
#Change MunicipalCodeFIPS dtype to add leading 0's
df_mlp_nc.loc[ :, 'MunicipalCodeFIPS'] = df_mlp_nc['MunicipalCodeFIPS'].astype(str)
df_mlp_nc.dtypes
# Out:
# c:\users\natha\appdata\local\programs\python\python38\lib\site-packages\pandas\core\indexing.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# RegionName            object
# State                 object
# Metro                 object
# StateCodeFIPS          int64
# MunicipalCodeFIPS     object
#                       ...
# 2019-07              float64
# 2019-08              float64
# 2019-09              float64
# 2019-10              float64
# 2019-11              float64
# Length: 125, dtype: object

# %%
#Add leading 0's and check to ensure they were added
df_mlp_nc.loc[ :, 'MunicipalCodeFIPS'] = df_mlp_nc['MunicipalCodeFIPS'].str.zfill(3)
df_mlp_nc.head(5)
# Out:
#              RegionName State                       Metro  StateCodeFIPS  \
# 48   Mecklenburg County    NC  Charlotte-Concord-Gastonia             37
# 55          Wake County    NC                     Raleigh             37
# 134     Guilford County    NC       Greensboro-High Point             37
# 183      Forsyth County    NC               Winston-Salem             37
# 198   Cumberland County    NC                Fayetteville             37
#
#     MunicipalCodeFIPS  SizeRank   2010-01   2010-02   2010-03   2010-04  ...  \
# 48                119        49  189900.0  194500.0  190000.0  194000.0  ...
# 55                183        56  247945.0  245000.0  239900.0  239900.0  ...
# 134               081       135  159900.0  159900.0  159900.0  159900.0  ...
# 183               067       184  154900.0  156800.0  159900.0  159900.0  ...
# 198               051       199       NaN       NaN       NaN       NaN  ...
#
#       2019-02   2019-03   2019-04   2019-05   2019-06   2019-07   2019-08  \
# 48   318990.0  318005.0  324999.0  321900.0  320000.0  318854.0  314999.0
# 55   357900.0  359000.0  364900.0  359900.0  359900.0  358490.0  357515.0
# 134  196900.0  208000.0  212945.0  214500.0  214379.0  214900.0  207900.0
# 183  200000.0  215000.0  224900.0  219900.0  225000.0  227400.0  220000.0
# 198  163000.0  165000.0  172000.0  169500.0  169000.0  168000.0  169000.0
#
#       2019-09   2019-10   2019-11
# 48   315000.0  315000.0  318999.0
# 55   359000.0  352990.0  350000.0
# 134  209700.0  214900.0  209900.0
# 183  216900.0  220000.0  225000.0
# 198  163000.0  161430.0  162900.0
#
# [5 rows x 125 columns]

# %%
# Set Index to Region Name
df_mlp_nc.set_index(df_mlp_nc['RegionName'], inplace = True)
df_mlp_nc
# Out:
#                             RegionName State                       Metro  \
# RegionName
# Mecklenburg County  Mecklenburg County    NC  Charlotte-Concord-Gastonia
# Wake County                Wake County    NC                     Raleigh
# Guilford County        Guilford County    NC       Greensboro-High Point
# Forsyth County          Forsyth County    NC               Winston-Salem
# Cumberland County    Cumberland County    NC                Fayetteville
# ...                                ...   ...                         ...
# Alleghany County      Alleghany County    NC                         NaN
# Clay County                Clay County    NC                         NaN
# Camden County            Camden County    NC              Elizabeth City
# Graham County            Graham County    NC                         NaN
# Hyde County                Hyde County    NC                         NaN
#
#                     StateCodeFIPS MunicipalCodeFIPS  SizeRank   2010-01  \
# RegionName
# Mecklenburg County             37               119        49  189900.0
# Wake County                    37               183        56  247945.0
# Guilford County                37               081       135  159900.0
# Forsyth County                 37               067       184  154900.0
# Cumberland County              37               051       199       NaN
# ...                           ...               ...       ...       ...
# Alleghany County               37               005      2093  229000.0
# Clay County                    37               043      2117  239800.0
# Camden County                  37               029      2139  275000.0
# Graham County                  37               075      2181  302450.0
# Hyde County                    37               095      2266       NaN
#
#                      2010-02   2010-03   2010-04  ...   2019-02   2019-03  \
# RegionName                                        ...
# Mecklenburg County  194500.0  190000.0  194000.0  ...  318990.0  318005.0
# Wake County         245000.0  239900.0  239900.0  ...  357900.0  359000.0
# Guilford County     159900.0  159900.0  159900.0  ...  196900.0  208000.0
# Forsyth County      156800.0  159900.0  159900.0  ...  200000.0  215000.0
# Cumberland County        NaN       NaN       NaN  ...  163000.0  165000.0
# ...                      ...       ...       ...  ...       ...       ...
# Alleghany County    227450.0  225900.0  235250.0  ...  236000.0  229000.0
# Clay County         239000.0  239000.0  239900.0  ...  249000.0  249999.0
# Camden County       274900.0  259900.0  259900.0  ...  297900.0  289900.0
# Graham County       289000.0  289000.0  272200.0  ...  264000.0  269000.0
# Hyde County              NaN       NaN       NaN  ...  364900.0  350000.0
#
#                      2019-04   2019-05   2019-06   2019-07   2019-08  \
# RegionName
# Mecklenburg County  324999.0  321900.0  320000.0  318854.0  314999.0
# Wake County         364900.0  359900.0  359900.0  358490.0  357515.0
# Guilford County     212945.0  214500.0  214379.0  214900.0  207900.0
# Forsyth County      224900.0  219900.0  225000.0  227400.0  220000.0
# Cumberland County   172000.0  169500.0  169000.0  168000.0  169000.0
# ...                      ...       ...       ...       ...       ...
# Alleghany County    237000.0  238000.0  244250.0  249000.0  248250.0
# Clay County         252000.0  252000.0  259000.0  259900.0  259000.0
# Camden County       285900.0  285900.0  279900.0  285900.0  289000.0
# Graham County       263000.0  249000.0  239000.0  239000.0  252000.0
# Hyde County         354950.0  364950.0  359900.0  365000.0  365000.0
#
#                      2019-09   2019-10   2019-11
# RegionName
# Mecklenburg County  315000.0  315000.0  318999.0
# Wake County         359000.0  352990.0  350000.0
# Guilford County     209700.0  214900.0  209900.0
# Forsyth County      216900.0  220000.0  225000.0
# Cumberland County   163000.0  161430.0  162900.0
# ...                      ...       ...       ...
# Alleghany County    237000.0  239000.0  238000.0
# Clay County         265000.0  259900.0  265000.0
# Camden County       289000.0  289900.0  292400.0
# Graham County       250000.0  249000.0  249000.0
# Hyde County         350000.0  345000.0  339950.0
#
# [88 rows x 125 columns]

# %%
# Drop Region Name column
df_mlp_nc.drop('RegionName', axis = 1, inplace = True)
df_mlp_nc
# Out:
# c:\users\natha\appdata\local\programs\python\python38\lib\site-packages\pandas\core\frame.py:4110: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#                    State                       Metro  StateCodeFIPS  \
# RegionName
# Mecklenburg County    NC  Charlotte-Concord-Gastonia             37
# Wake County           NC                     Raleigh             37
# Guilford County       NC       Greensboro-High Point             37
# Forsyth County        NC               Winston-Salem             37
# Cumberland County     NC                Fayetteville             37
# ...                  ...                         ...            ...
# Alleghany County      NC                         NaN             37
# Clay County           NC                         NaN             37
# Camden County         NC              Elizabeth City             37
# Graham County         NC                         NaN             37
# Hyde County           NC                         NaN             37
#
#                    MunicipalCodeFIPS  SizeRank   2010-01   2010-02   2010-03  \
# RegionName
# Mecklenburg County               119        49  189900.0  194500.0  190000.0
# Wake County                      183        56  247945.0  245000.0  239900.0
# Guilford County                  081       135  159900.0  159900.0  159900.0
# Forsyth County                   067       184  154900.0  156800.0  159900.0
# Cumberland County                051       199       NaN       NaN       NaN
# ...                              ...       ...       ...       ...       ...
# Alleghany County                 005      2093  229000.0  227450.0  225900.0
# Clay County                      043      2117  239800.0  239000.0  239000.0
# Camden County                    029      2139  275000.0  274900.0  259900.0
# Graham County                    075      2181  302450.0  289000.0  289000.0
# Hyde County                      095      2266       NaN       NaN       NaN
#
#                      2010-04   2010-05  ...   2019-02   2019-03   2019-04  \
# RegionName                              ...
# Mecklenburg County  194000.0  190000.0  ...  318990.0  318005.0  324999.0
# Wake County         239900.0  244900.0  ...  357900.0  359000.0  364900.0
# Guilford County     159900.0  159900.0  ...  196900.0  208000.0  212945.0
# Forsyth County      159900.0  158354.0  ...  200000.0  215000.0  224900.0
# Cumberland County        NaN       NaN  ...  163000.0  165000.0  172000.0
# ...                      ...       ...  ...       ...       ...       ...
# Alleghany County    235250.0  229900.0  ...  236000.0  229000.0  237000.0
# Clay County         239900.0  239900.0  ...  249000.0  249999.0  252000.0
# Camden County       259900.0  250000.0  ...  297900.0  289900.0  285900.0
# Graham County       272200.0  269900.0  ...  264000.0  269000.0  263000.0
# Hyde County              NaN       NaN  ...  364900.0  350000.0  354950.0
#
#                      2019-05   2019-06   2019-07   2019-08   2019-09  \
# RegionName
# Mecklenburg County  321900.0  320000.0  318854.0  314999.0  315000.0
# Wake County         359900.0  359900.0  358490.0  357515.0  359000.0
# Guilford County     214500.0  214379.0  214900.0  207900.0  209700.0
# Forsyth County      219900.0  225000.0  227400.0  220000.0  216900.0
# Cumberland County   169500.0  169000.0  168000.0  169000.0  163000.0
# ...                      ...       ...       ...       ...       ...
# Alleghany County    238000.0  244250.0  249000.0  248250.0  237000.0
# Clay County         252000.0  259000.0  259900.0  259000.0  265000.0
# Camden County       285900.0  279900.0  285900.0  289000.0  289000.0
# Graham County       249000.0  239000.0  239000.0  252000.0  250000.0
# Hyde County         364950.0  359900.0  365000.0  365000.0  350000.0
#
#                      2019-10   2019-11
# RegionName
# Mecklenburg County  315000.0  318999.0
# Wake County         352990.0  350000.0
# Guilford County     214900.0  209900.0
# Forsyth County      220000.0  225000.0
# Cumberland County   161430.0  162900.0
# ...                      ...       ...
# Alleghany County    239000.0  238000.0
# Clay County         259900.0  265000.0
# Camden County       289900.0  292400.0
# Graham County       249000.0  249000.0
# Hyde County         345000.0  339950.0
#
# [88 rows x 124 columns]

# %%
#Save to csv file for export in Excel
#df_mlp_nc.to_csv('./Updates/STG_ZLLW_County_MedianListingPrice_AllHomes.txt', sep ='\t')
