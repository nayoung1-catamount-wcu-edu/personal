# %%
#Imports
import pandas as pd

# %%
#Load Land data
df_mlsf = pd.read_excel('./Data/County_MedianListingPricePerSqft_AllHomes.xlsx')

#Display table to ensure data loaded correctly
df_mlsf.head()
# Out:
#            RegionName State                             Metro  StateCodeFIPS  \
# 0  Los Angeles County    CA    Los Angeles-Long Beach-Anaheim              6
# 1         Cook County    IL          Chicago-Naperville-Elgin             17
# 2       Harris County    TX  Houston-The Woodlands-Sugar Land             48
# 3     Maricopa County    AZ           Phoenix-Mesa-Scottsdale              4
# 4    San Diego County    CA                San Diego-Carlsbad              6
#
#    MunicipalCodeFIPS  SizeRank     2010-01     2010-02     2010-03  \
# 0                 37         1  268.325184  262.878386  268.901013
# 1                 31         2  188.180918  189.909091  190.117754
# 2                201         3   75.429769   76.247689   76.482328
# 3                 13         4   99.295135   97.665701   96.704871
# 4                 73         5  246.596629  249.448124  250.882659
#
#       2010-04  ...     2018-11     2018-12     2019-01     2019-02  \
# ...

# %%
#Filter data to NC
filter1 = df_mlsf['State'] == "NC"
df_mlsf_nc = df_mlsf[filter1]

#Check to ensure filter worked
df_mlsf_nc.head(5)
# Out:
#              RegionName State                       Metro  StateCodeFIPS  \
# 48   Mecklenburg County    NC  Charlotte-Concord-Gastonia             37
# 55          Wake County    NC                     Raleigh             37
# 134     Guilford County    NC       Greensboro-High Point             37
# 182      Forsyth County    NC               Winston-Salem             37
# 197   Cumberland County    NC                Fayetteville             37
#
#      MunicipalCodeFIPS  SizeRank     2010-01     2010-02     2010-03  \
# 48                 119        49  102.245863  103.129161  102.739998
# 55                 183        56  116.579266  116.021672  115.858799
# 134                 81       135   92.497818   92.846630   93.487395
# 182                 67       183   97.085603   97.529259   98.072880
# 197                 51       198   91.267001   91.360214   91.689655
#
#         2010-04  ...     2018-11     2018-12     2019-01     2019-02  \
# ...

# %%
#Change MunicipalCodeFIPS dtype to add leading 0's
df_mlsf_nc['MunicipalCodeFIPS'] = df_mlsf_nc['MunicipalCodeFIPS'].astype(str)
# Out:
# c:\users\natha\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#Add leading 0's and check to ensure they were added
df_mlsf_nc['MunicipalCodeFIPS'] = df_mlsf_nc['MunicipalCodeFIPS'].str.zfill(3)
df_mlsf_nc.head(5)
# Out:
# c:\users\natha\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#              RegionName State                       Metro  StateCodeFIPS  \
# 48   Mecklenburg County    NC  Charlotte-Concord-Gastonia             37
# 55          Wake County    NC                     Raleigh             37
# 134     Guilford County    NC       Greensboro-High Point             37
# 182      Forsyth County    NC               Winston-Salem             37
# 197   Cumberland County    NC                Fayetteville             37
#
#     MunicipalCodeFIPS  SizeRank     2010-01     2010-02     2010-03  \
# 48                119        49  102.245863  103.129161  102.739998
# ...

# %%
#Save to csv file for export in Excel
df_mlsf_nc.to_csv('./Data/STG_ZLLW_County_MedianListingPricePerSqft_AllHomes.txt')
