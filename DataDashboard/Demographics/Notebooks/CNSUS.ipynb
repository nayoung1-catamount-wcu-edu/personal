# %%
import pandas as pd

# %%
# Create Backups
#df_backup = pd.read_csv('', encoding = 'ISO-8859-1', sep='\t')
#df_backup.to_csv('')

# %% [markdown]
# # United States

# %%
# Load data
df_nc_1 = pd.read_csv('../Data/PEP_2018_PEPAGESEX_with_ann_us.csv')
df_nc_1.head()
# Out:
#       GEO.id  GEO.id2 GEO.display-label  cen42010sex0_age999  \
# 0  0100000US      NaN     United States            308745538
#
#    cen42010sex1_age999  cen42010sex2_age999  est42010sex0_age999  \
# 0            151781326            156964212            308758105
#
#    est42010sex1_age999  est42010sex2_age999  est72010sex0_age999  ...  \
# 0            151788777            156969328            309326085  ...
#
#    est72015sex2_medage  est72016sex0_medage  est72016sex1_medage  \
# 0                 39.1                 37.9                 36.6
#
#    est72016sex2_medage  est72017sex0_medage  est72017sex1_medage  \
# 0                 39.2                 38.0                 36.8
#
#    est72017sex2_medage  est72018sex0_medage  est72018sex1_medage  \
# 0                 39.4                 38.2                 36.9
#
#    est72018sex2_medage
# 0                 39.5
#
# [1 rows x 1092 columns]

# %%
df_nc_2 = pd.read_csv('../Data/PEP_2018_PEPSR6H_with_ann_us.csv')
df_nc_2.head()
# Out:
#     Year.id    Year.display-label  Sex.id Sex.display-label  Hisp.id  \
# 0  cen42010  April 1, 2010 Census  female            Female     hisp
# 1  cen42010  April 1, 2010 Census  female            Female    nhisp
# 2  cen42010  April 1, 2010 Census  female            Female  tothisp
# 3  cen42010  April 1, 2010 Census    male              Male     hisp
# 4  cen42010  April 1, 2010 Census    male              Male    nhisp
#
#   Hisp.display-label     GEO.id  GEO.id2 GEO.display-label     totpop  \
# 0           Hispanic  0100000US      NaN     United States   24858794
# 1       Not Hispanic  0100000US      NaN     United States  132105418
# 2              Total  0100000US      NaN     United States  156964212
# 3           Hispanic  0100000US      NaN     United States   25618800
# 4       Not Hispanic  0100000US      NaN     United States  126162526
#
#           wa        ba       ia       aa      na      tom
# 0   21936806   1191984   702309   249346   85203   693146
# 1  100301335  19853611  1147502  7691693  246518  2864759
# 2  122238141  21045595  1849811  7941039  331721  3557905
# 3   22681299   1136129   773939   248654   92206   686573
# 4   97017621  18068911  1115756  6969823  250698  2739717

# %% [markdown]
# # North Carolina

# %%
df_us_1 = pd.read_csv('../Data/PEP_2018_PEPAGESEX_with_ann_nc.csv')
df_us_1.head()
# Out:
#    GeoArea_FIPS    GeoArea_Name  April 1, 2010 - Census - Both Sexes; Total  \
# 0            37  North Carolina                                     9535483
#
#    April 1, 2010 - Census - Male; Total  \
# 0                               4645492
#
#    April 1, 2010 - Census - Female; Total  \
# 0                                 4889991
#
#    April 1, 2010 - Estimates Base - Both Sexes; Total  \
# 0                                            9535736
#
#    April 1, 2010 - Estimates Base - Male; Total  \
# 0                                       4645610
#
#    April 1, 2010 - Estimates Base - Female; Total  \
# 0                                         4890126
#
#    Population Estimate (as of July 1) - 2010 - Both Sexes; Total  \
# 0                                            9574293
#
#    Population Estimate (as of July 1) - 2010 - Male; Total  ...  \
# 0                                            4670084        ...
#
#    Population Estimate (as of July 1) - 2015 - Female; Median age (years)  \
# 0                                               39.9
#
#    Population Estimate (as of July 1) - 2016 - Both Sexes; Median age (years)  \
# 0                                               38.6
#
#    Population Estimate (as of July 1) - 2016 - Male; Median age (years)  \
# 0                                                 37
#
#    Population Estimate (as of July 1) - 2016 - Female; Median age (years)  \
# 0                                                 40
#
#    Population Estimate (as of July 1) - 2017 - Both Sexes; Median age (years)  \
# 0                                               38.7
#
#    Population Estimate (as of July 1) - 2017 - Male; Median age (years)  \
# 0                                               37.2
#
#    Population Estimate (as of July 1) - 2017 - Female; Median age (years)  \
# 0                                               40.2
#
#    Population Estimate (as of July 1) - 2018 - Both Sexes; Median age (years)  \
# 0                                               38.9
#
#    Population Estimate (as of July 1) - 2018 - Male; Median age (years)  \
# 0                                               37.4
#
#    Population Estimate (as of July 1) - 2018 - Female; Median age (years)
# 0                                               40.4
#
# [1 rows x 1091 columns]

# %%
df_us_2 = pd.read_csv('../Data/PEP_2018_PEPSR6H_with_ann_nc.csv')
df_us_2.head()
# Out:
#          Id                  Year    Id.1     Sex     Id.2 Hispanic Origin  \
# 0  cen42010  April 1, 2010 Census  female  Female     hisp        Hispanic
# 1  cen42010  April 1, 2010 Census  female  Female    nhisp    Not Hispanic
# 2  cen42010  April 1, 2010 Census  female  Female  tothisp           Total
# 3  cen42010  April 1, 2010 Census    male    Male     hisp        Hispanic
# 4  cen42010  April 1, 2010 Census    male    Male    nhisp    Not Hispanic
#
#           Id.3  Id2       Geography    Total  Race Alone - White  \
# 0  0400000US37   37  North Carolina   372385              306402
# 1  0400000US37   37  North Carolina  4517606             3193471
# 2  0400000US37   37  North Carolina  4889991             3499873
# 3  0400000US37   37  North Carolina   427735              356225
# 4  0400000US37   37  North Carolina  4217757             3042198
#
#    Race Alone - Black or African American  \
# 0                                   30519
# 1                                 1078687
# 2                                 1109206
# 3                                   31125
# 4                                  948031
#
#    Race Alone - American Indian and Alaska Native  Race Alone - Asian  \
# 0                                           17301                3066
# 1                                           56405              109311
# 2                                           73706              112377
# 3                                           20917                3494
# 4                                           52943              100081
#
#    Race Alone - Native Hawaiian and Other Pacific Islander  Two or More Races
# 0                                               2188                    12909
# 1                                               2699                    77033
# 2                                               4887                    89942
# 3                                               2677                    13297
# 4                                               2745                    71759

# %% [markdown]
# # Counties

# %%
df_co_1 = pd.read_csv('../Data/PEP_2018_PEPAGESEX_with_ann_county.csv')
df_co_1.head()
# Out:
#            GEO.id  GEO.id2                 GEO.display-label  \
# 0  0500000US37001    37001   Alamance County, North Carolina
# 1  0500000US37003    37003  Alexander County, North Carolina
# 2  0500000US37005    37005  Alleghany County, North Carolina
# 3  0500000US37007    37007      Anson County, North Carolina
# 4  0500000US37009    37009       Ashe County, North Carolina
#
#    cen42010sex0_age999  cen42010sex1_age999  cen42010sex2_age999  \
# 0               151131                71890                79241
# 1                37198                18824                18374
# 2                11155                 5532                 5623
# 3                26948                14015                12933
# 4                27281                13489                13792
#
#    est42010sex0_age999  est42010sex1_age999  est42010sex2_age999  \
# 0               151160                71906                79254
# 1                37185                18819                18366
# 2                11154                 5532                 5622
# 3                26929                14007                12922
# 4                27240                13463                13777
#
#    est72010sex0_age999  ...  est72015sex2_medage  est72016sex0_medage  \
# 0               151440  ...                 41.1                 39.4
# 1                37235  ...                 44.8                 43.6
# 2                11139  ...                 50.8                 49.8
# 3                26852  ...                 43.8                 41.0
# 4                27228  ...                 49.4                 48.3
#
#    est72016sex1_medage  est72016sex2_medage  est72017sex0_medage  \
# 0                 37.9                 40.7                 39.3
# 1                 42.2                 45.2                 43.9
# 2                 48.4                 51.2                 50.1
# 3                 38.8                 44.0                 41.1
# 4                 46.8                 49.9                 48.8
#
#    est72017sex1_medage  est72017sex2_medage  est72018sex0_medage  \
# 0                 37.8                 40.7                 39.3
# 1                 42.3                 45.5                 44.1
# 2                 48.6                 51.6                 50.5
# 3                 38.8                 44.3                 41.2
# 4                 47.3                 50.4                 49.0
#
#    est72018sex1_medage  est72018sex2_medage
# 0                 37.8                 40.6
# 1                 42.4                 45.8
# 2                 48.9                 51.9
# 3                 38.8                 44.5
# 4                 47.6                 50.7
#
# [5 rows x 1092 columns]

# %%
df_co_2 = pd.read_csv('../Data/PEP_2018_PEPSR6H_with_ann_county.csv')
df_co_2.head()
# Out:
#     Year.id    Year.display-label  Sex.id Sex.display-label  Hisp.id  \
# 0  cen42010  April 1, 2010 Census  female            Female     hisp
# 1  cen42010  April 1, 2010 Census  female            Female    nhisp
# 2  cen42010  April 1, 2010 Census  female            Female  tothisp
# 3  cen42010  April 1, 2010 Census    male              Male     hisp
# 4  cen42010  April 1, 2010 Census    male              Male    nhisp
#
#   Hisp.display-label          GEO.id  GEO.id2  \
# 0           Hispanic  0500000US37001    37001
# 1       Not Hispanic  0500000US37001    37001
# 2              Total  0500000US37001    37001
# 3           Hispanic  0500000US37001    37001
# 4       Not Hispanic  0500000US37001    37001
#
#                  GEO.display-label  totpop     wa     ba    ia    aa  na   tom
# 0  Alamance County, North Carolina    8116   6600    423   736    36  27   294
# 1  Alamance County, North Carolina   71125  53553  15185   290   989  26  1082
# 2  Alamance County, North Carolina   79241  60153  15608  1026  1025  53  1376
# 3  Alamance County, North Carolina    8523   6969    425   782    41  17   289
# 4  Alamance County, North Carolina   63367  48320  12893   259   859  30  1006
