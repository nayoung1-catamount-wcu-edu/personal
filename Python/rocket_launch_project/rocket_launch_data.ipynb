# %%
import pandas as pd
import requests 
import json

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
base_url = "https://lldev.thespacedevs.com/2.2.0/launch/previous"

# %% [markdown]
# ***

# %% [markdown]
# response = requests.get(base_url)

# %% [markdown]
# json_data = json.loads(response.text)
# #json_data

# %% [markdown]
# df = pd.json_normalize(json_data['results'])
#
# df.to_csv('./data/rocket_launch_data.csv')

# %%
df = pd.read_csv("./data/rocket_launch_data.csv")

# %%
#df.columns.to_list()

# %%
columns_to_keep = ['name', 'window_start', 'window_end', 'status.name', 'launch_service_provider.name', 'rocket.configuration.name', 'mission.name', 'pad.name', 'pad.latitude', 'pad.longitude', 'pad.location.name']

# %%
df = df[columns_to_keep]
df
# Out:
#                                      name          window_start  \
# 0       Soyuz 2.1a | Progress MS-24 (85P)  2023-08-23T01:08:00Z
# 1  Falcon 9 Block 5 | Starlink Group 6-11  2023-08-23T00:47:00Z
# 2   Falcon 9 Block 5 | Starlink Group 7-1  2023-08-22T06:04:00Z
# 3  Falcon 9 Block 5 | Starlink Group 6-10  2023-08-17T00:14:50Z
# 4           Kuaizhou-1A | HEAD-3A/B/C/D/E  2023-08-14T05:22:00Z
# 5   Long March 3B/E | L-SAR4-01 (LTDC-4A)  2023-08-12T16:46:00Z
# 6   Falcon 9 Block 5 | Starlink Group 6-9  2023-08-11T05:17:40Z
# 7           Soyuz 2.1b/Fregat-M | Luna 25  2023-08-10T23:10:57Z
# 8              SpaceShipTwo | Galactic 02  2023-08-10T14:00:00Z
# 9                  Ceres-1 | 7 satellites  2023-08-10T03:00:00Z
#
#              window_end        status.name  \
# 0  2023-08-23T01:08:00Z      Go for Launch
# 1  2023-08-23T05:00:00Z   To Be Determined
# 2  2023-08-22T06:04:00Z    To Be Confirmed
# 3  2023-08-17T04:00:00Z  Launch Successful
# ...

# %% [markdown]
# ***

# %% [markdown]
# def get_results(url):
#
#     response = requests.get(url)
#
#     if '40' in response:
#         print(response)
#         exit()
#     else:
#          pass
#
#     clean_data = json.loads(response.text)
#
#     data = pd.json_normalize(clean_data['results'])
#
#     return data

# %% [markdown]
# get_results(base_url)
